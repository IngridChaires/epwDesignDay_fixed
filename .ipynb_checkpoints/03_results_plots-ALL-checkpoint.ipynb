# %%
from os import path
import os
import pandas as pd
import numpy as np
import requests, zipfile, io, os
pd.set_option('display.max_colwidth', -1)
import matplotlib as mpl
import matplotlib.pyplot as plt
from datetime import datetime
import re
import seaborn as sns
# Out:
# /var/folders/mk/7yynft554x38v3t6f_65fkzc0000gn/T/ipykernel_29161/3265537112.py:6: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df_epwDD = pd.read_csv('AllRegion_Results.csv') 
df_epwDD
# Out:
#                                                  Location Name  \
# 0      Esperanza.Base-Hope.Bay ARG ATA
# 1      Esperanza.Base-Hope.Bay ARG ATA
# 2      Orcadas.Base-Laurie.Island-South.Orkney.Islands ARG ATA
# 3      Orcadas.Base-Laurie.Island-South.Orkney.Islands ARG ATA
# 4      Orcadas.Base-Laurie.Island-South.Orkney.Islands ARG ATA
# ...                                                        ...
# 30457  Montreal-Mirabel Intl AP QC CAN
# 30458  Slave Lake AB CAN
# 30459  Wainwright CFB Airfield AB CAN
# 30460  Grand Etang NS CAN
# 30461  Malay Falls NS CAN
#
#                               Coordinates  \
# 0      ['-56.99730', '-63.39810', '3.0']
# 1      ['-56.99730', '-63.39810', '3.0']
# 2      ['-44.73300', '-60.73300', '8.0']
# 3      ['-44.73300', '-60.73300', '8.0']
# 4      ['-44.73300', '-60.73300', '8.0']
# ...                                  ...
# 30457  ['-74.03860', '45.68060', '82.3']
# 30458  ['-114.7800', '55.29000', '582.8']
# 30459  ['-111.1000', '52.83000', '686.3']
# 30460  ['-61.05000', '46.55000', '12.5']
# 30461  ['-62.48000', '44.98000', '39.6']
#
#                                                                                                                                                   URL for files  \
# 0      https://climate.onebuilding.org/WMO_Region_7_Antarctica/ATA_Antarctica/ATA_ARG_Esperanza.Base-Hope.Bay.889630_TMYx.2007-2021.zip
# 1      https://climate.onebuilding.org/WMO_Region_7_Antarctica/ATA_Antarctica/ATA_ARG_Esperanza.Base-Hope.Bay.889630_TMYx.zip
# 2      https://climate.onebuilding.org/WMO_Region_7_Antarctica/ATA_Antarctica/ATA_ARG_Orcadas.Base-Laurie.Island-South.Orkney.Islands.889680_TMYx.2004-2018.zip
# 3      https://climate.onebuilding.org/WMO_Region_7_Antarctica/ATA_Antarctica/ATA_ARG_Orcadas.Base-Laurie.Island-South.Orkney.Islands.889680_TMYx.2007-2021.zip
# 4      https://climate.onebuilding.org/WMO_Region_7_Antarctica/ATA_Antarctica/ATA_ARG_Orcadas.Base-Laurie.Island-South.Orkney.Islands.889680_TMYx.zip
# ...                                                                                                                                               ...
# 30457  https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/CAN_Canada/QC_Quebec/CAN_QC_Montreal-Mirabel.Intl.AP.719050_CWEC2016.zip
# 30458  https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/CAN_Canada/AB_Alberta/CAN_AB_Slave.Lake.713690_CWEC2020.zip
# 30459  https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/CAN_Canada/AB_Alberta/CAN_AB_Wainwright.CFB.Airfield.711180_CWEC2020.zip
# 30460  https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/CAN_Canada/NS_Nova_Scotia/CAN_NS_Grand.Etang.730300_CWEC2020.zip
# 30461  https://climate.onebuilding.org/WMO_Region_4_North_and_Central_America/CAN_Canada/NS_Nova_Scotia/CAN_NS_Malay.Falls.730290_CWEC2020.zip
#
#           WMO last_year     Country State/Province         Station   WBAN  \
# 0      889630  2021      Antarctica  NaN            BASE ESPERANZA  99999
# 1      889630  TMYx      Antarctica  NaN            BASE ESPERANZA  99999
# 2      889680  2018      Antarctica  NaN            BASE ORCADAS    99999
# 3      889680  2021      Antarctica  NaN            BASE ORCADAS    99999
# 4      889680  TMYx      Antarctica  NaN            BASE ORCADAS    99999
# ...       ...   ...             ...  ...                     ...      ...
# 30457  719050  2016      Canada      QC             KUUJJUARAPIK    99999
# 30458  713690  2020      Canada      AB             SLAVE LAKE      99999
# 30459  711180  2020      Canada      AB             WAINWRIGHT CFB  99999
# 30460  730300  2020      Canada      NS             GRAND ETANG     99999
# 30461  730290  2020      Canada      NS             MALAY FALLS     99999
#
#        Latitude  ... Evaporation WB 0.4%  Evaporation MCDB 0.4%  \
# 0      63.3989S  ...  4.7                 7.5
# 1      63.3989S  ...  4.7                 7.5
# 2      60.7378S  ...  4.1                 5.3
# 3      60.7378S  ...  4.1                 5.3
# 4      60.7378S  ...  4.1                 5.3
# ...         ...  ...  ...                 ...
# 30457  55.282N   ...  18.3                22.9
# 30458  55.2964N  ...  18.8                24.2
# 30459  52.8305N  ...  19.0                26.2
# 30460  46.550N   ...  22.4                25.4
# 30461  44.980N   ...  22.1                25.8
#
#        Evaporation WB 1%  Evaporation MCDB 1%  Evaporation WB 2%  \
# 0      3.9                6.4                  3.2
# 1      3.9                6.4                  3.2
# 2      3.4                4.3                  2.8
# 3      3.4                4.3                  2.8
# 4      3.4                4.3                  2.8
# ...    ...                ...                  ...
# 30457  17.0               21.0                 15.6
# 30458  17.8               22.8                 16.7
# 30459  18.0               25.1                 17.0
# 30460  21.6               24.4                 20.7
# 30461  21.1               24.3                 20.2
#
#        Evaporation MCDB 2%  Heating DB 99.6% - EPW  Heating DB 99% - EPW  \
# 0      5.4                 -22.8964                -21.100
# 1      5.4                 -22.2964                -21.300
# 2      3.6                 -26.8000                -24.241
# 3      3.6                 -27.3964                -24.900
# 4      3.6                 -22.9000                -20.900
# ...    ...                      ...                    ...
# 30457  19.7                -24.9000                -21.700
# 30458  21.4                -27.3964                -25.300
# 30459  23.7                -28.7000                -26.300
# 30460  23.5                -12.3000                -11.500
# 30461  23.0                -16.5892                -14.400
#
#        Cooling DB 0.4% - EPW  Cooling DB 1% - EPW
# 0      7.6000                 6.741
# 1      7.3000                 6.200
# 2      5.3964                 4.300
# 3      4.6000                 3.900
# 4      6.3000                 4.941
# ...       ...                   ...
# 30457  28.8000                27.500
# 30458  26.4000                24.241
# 30459  29.8000                28.000
# 30460  26.1000                24.700
# 30461  27.2000                26.000
#
# [30462 rows x 29 columns]

# %%
df_results['Location Name'].nunique()

# %%
df_results['Region_number'] = df_results['WMO'].astype(str).str[:2]

# %%
df_results= df_results.sort_values(by=['Region_number'], ascending=False)
df_results.drop(df_results.index[df_results['Region_number'] == 'WM'], inplace = True)
df_results['Region_number']= df_results['Region_number'].astype(str).astype(int,errors='ignore')
df_results.dtypes
# Out:
# Location Name             object
# Coordinates               object
# WMO                       object
# last_year                 object
# Country                   object
# Latitude                  object
# Longitude                 object
# Heating DB 99.6%          object
# Heating DB 99%            object
# Cooling DB 0.4%           object
# Cooling MCWB 0.4%         object
# Cooling DB 1%             object
# Cooling MCWB 1%           object
# Cooling DB 2%             object
# Cooling MCWB 2%           object
# Evaporation WB 0.4%       object
# Evaporation MCDB 0.4%     object
# Evaporation WB 1%         object
# Evaporation MCDB 1%       object
# Evaporation WB 2%         object
# Evaporation MCDB 2%       object
# Heating DB 99.6% - EPW    object
# Heating DB 99% - EPW      object
# Cooling DB 0.4% - EPW     object
# Cooling DB 1% - EPW       object
# Region_number             int64
# dtype: object

# %%
df_results["Region"] = pd.cut(
    x=df_results["Region_number"],
    bins=[0, 29, 59,68,69,79,89,99, np.inf],
    labels=["Europe", "Asia", "Africa","special","North America","South America","Oceania","other"],
)
df_results
# Out:
#                             Location Name                         Coordinates  \
# 26468  Philadelphia.Harbor PA USA          ['-75.14200', '39.93300', '20.0']
# 26419  Santa.Rosa.Island CA USA            ['-120.1030', '33.93890', '236.0']
# 26430  Marquette.Harbor.Lighthouse MI USA  ['-87.37625', '46.54660', '187.5']
# 26429  CGS.Ludington MI USA                ['-86.44100', '43.94700', '179.4']
# 26428  Ludington.Harbor MI USA             ['-86.44100', '43.94700', '179.4']
# ...                        ...                                            ...
# 185    Koln.Bonn.AP NW DEU                 ['7.15750', '50.86440', '99.5']
# 184    Koln.Bonn.AP NW DEU                 ['7.15750', '50.86440', '99.5']
# 183    Koln.Bonn.AP NW DEU                 ['7.15750', '50.86440', '99.5']
# 182    Nurburg.Barweiler RP DEU            ['6.86970', '50.36030', '488.2']
# 0      Bremerhaven HB DEU                  ['8.58300', '53.53300', '5.0']
#
#           WMO                                       last_year  Country  \
# 26468  997286  2021                                            USA
# 26419  997199  2021                                            USA
# 26430  997262  2018                                            USA
# 26429  997261  997261_TMYx                                     USA
# 26428  997261  2021                                            USA
# ...       ...   ...                                            ...
# 185    105130  2018                                            Germany
# 184    105130  2021                                            Germany
# 183    105130  105130_TMYx                                     Germany
# 182    105060  2018                                            Germany
# 0      101290  DEU_HB_Bremerhaven_101290_TRY2010_01_Somm_BBSR  Germany
#
#        Latitude Longitude Heating DB 99.6% Heating DB 99% Cooling DB 0.4%  \
# 26468  39.9330N  75.1420W  -9.4             -7.2           35.3
# 26419  33.677N   120.213W  9.9              10.3           20.5
# 26430  46.546N   87.379W   -20.0            -17.9          27.5
# 26429  43.947N   86.441W   -15.3            -13.2          27.0
# 26428  43.947N   86.441W   -15.3            -13.2          27.0
# ...        ...       ...     ...              ...           ...
# 185    50.8644N  7.1575E   -8.0             -5.8           31.1
# 184    50.8644N  7.1575E   -8.0             -5.8           31.1
# 183    50.8644N  7.1575E   -8.0             -5.8           31.1
# 182    50.3603N  6.8697E   -9.7             -7.7           27.6
# 0      53.5333N  8.5761E   -9.4             -7.0           27.2
#
#        ... Evaporation WB 1% Evaporation MCDB 1% Evaporation WB 2%  \
# 26468  ...  NaN               NaN                 NaN
# 26419  ...  NaN               NaN                 NaN
# 26430  ...  NaN               NaN                 NaN
# 26429  ...  NaN               NaN                 NaN
# 26428  ...  NaN               NaN                 NaN
# ...    ...  ...               ...                 ...
# 185    ...  20.1              26.4                19.2
# 184    ...  20.1              26.4                19.2
# 183    ...  20.1              26.4                19.2
# 182    ...  18.2              23.5                17.4
# 0      ...  19.2              23.2                18.3
#
#       Evaporation MCDB 2% Heating DB 99.6% - EPW Heating DB 99% - EPW  \
# 26468  NaN                 -6.6                   -4.840999999999999
# 26419  NaN                 10.2072                11.0
# 26430  NaN                 -19.6964               -18.2
# 26429  NaN                 -12.1                  -10.7
# 26428  NaN                 -13.5                  -11.6
# ...    ...                   ...                    ...
# 185    25.0                -5.963999999999999     -3.0
# 184    25.0                -5.0                   -4.0
# 183    25.0                -6.0                   -4.0
# 182    22.1                -7.5                   -5.941
# 0      22.0                -8.1                   -5.9
#
#       Cooling DB 0.4% - EPW Cooling DB 1% - EPW Region_number   Region
# 26468  35.1                  33.9                99            Oceania
# 26419  19.9                  18.6                99            Oceania
# 26430  27.3                  25.340999999999987  99            Oceania
# 26429  26.7                  25.840999999999987  99            Oceania
# 26428  27.0                  26.0                99            Oceania
# ...     ...                   ...                ..                ...
# 185    30.0                  28.0                10            Europe
# 184    30.0                  28.0                10            Europe
# 183    29.8                  27.840999999999987  10            Europe
# 182    25.4                  23.940999999999985  10            Europe
# 0      30.1964               27.840999999999987  10            Europe
#
# [30463 rows x 27 columns]

# %%
cols = df_results.columns.drop(['Location Name','Coordinates','WMO','last_year','Country','Latitude','Longitude','Region_number','Region'])
df_results[cols] = df_results[cols].apply(pd.to_numeric)
df_results.dtypes
# Out:
# Location Name             object
# Coordinates               object
# WMO                       object
# last_year                 object
# Country                   object
# Latitude                  object
# Longitude                 object
# Heating DB 99.6%          float64
# Heating DB 99%            float64
# Cooling DB 0.4%           float64
# Cooling MCWB 0.4%         float64
# Cooling DB 1%             float64
# Cooling MCWB 1%           float64
# Cooling DB 2%             float64
# Cooling MCWB 2%           float64
# Evaporation WB 0.4%       float64
# Evaporation MCDB 0.4%     float64
# Evaporation WB 1%         float64
# Evaporation MCDB 1%       float64
# Evaporation WB 2%         float64
# Evaporation MCDB 2%       float64
# Heating DB 99.6% - EPW    float64
# Heating DB 99% - EPW      float64
# Cooling DB 0.4% - EPW     float64
# Cooling DB 1% - EPW       float64
# Region_number             int64
# Region                    category
# dtype: object

# %%
df_results['last_year'] = df_results['last_year'].astype('string')
#df_results['last_year'] = df_results['last_year'].str.replace('TMYx','-')
df_results['last_year'] = df_results['last_year'].str[-4:]

df_results
# Out:
#                             Location Name                         Coordinates  \
# 26468  Philadelphia.Harbor PA USA          ['-75.14200', '39.93300', '20.0']
# 26419  Santa.Rosa.Island CA USA            ['-120.1030', '33.93890', '236.0']
# 26430  Marquette.Harbor.Lighthouse MI USA  ['-87.37625', '46.54660', '187.5']
# 26429  CGS.Ludington MI USA                ['-86.44100', '43.94700', '179.4']
# 26428  Ludington.Harbor MI USA             ['-86.44100', '43.94700', '179.4']
# ...                        ...                                            ...
# 185    Koln.Bonn.AP NW DEU                 ['7.15750', '50.86440', '99.5']
# 184    Koln.Bonn.AP NW DEU                 ['7.15750', '50.86440', '99.5']
# 183    Koln.Bonn.AP NW DEU                 ['7.15750', '50.86440', '99.5']
# 182    Nurburg.Barweiler RP DEU            ['6.86970', '50.36030', '488.2']
# 0      Bremerhaven HB DEU                  ['8.58300', '53.53300', '5.0']
#
#           WMO last_year  Country  Latitude Longitude  Heating DB 99.6%  \
# 26468  997286  2021      USA      39.9330N  75.1420W -9.4
# 26419  997199  2021      USA      33.677N   120.213W  9.9
# 26430  997262  2018      USA      46.546N   87.379W  -20.0
# 26429  997261  TMYx      USA      43.947N   86.441W  -15.3
# 26428  997261  2021      USA      43.947N   86.441W  -15.3
# ...       ...   ...      ...          ...       ...    ...
# 185    105130  2018      Germany  50.8644N  7.1575E  -8.0
# 184    105130  2021      Germany  50.8644N  7.1575E  -8.0
# 183    105130  TMYx      Germany  50.8644N  7.1575E  -8.0
# 182    105060  2018      Germany  50.3603N  6.8697E  -9.7
# 0      101290  BBSR      Germany  53.5333N  8.5761E  -9.4
#
#        Heating DB 99%  Cooling DB 0.4%  ...  Evaporation WB 1%  \
# 26468 -7.2             35.3             ... NaN
# 26419  10.3            20.5             ... NaN
# 26430 -17.9            27.5             ... NaN
# 26429 -13.2            27.0             ... NaN
# 26428 -13.2            27.0             ... NaN
# ...     ...             ...             ...  ..
# 185   -5.8             31.1             ...  20.1
# 184   -5.8             31.1             ...  20.1
# 183   -5.8             31.1             ...  20.1
# 182   -7.7             27.6             ...  18.2
# 0     -7.0             27.2             ...  19.2
#
#        Evaporation MCDB 1%  Evaporation WB 2%  Evaporation MCDB 2%  \
# 26468 NaN                  NaN                NaN
# 26419 NaN                  NaN                NaN
# 26430 NaN                  NaN                NaN
# 26429 NaN                  NaN                NaN
# 26428 NaN                  NaN                NaN
# ...    ..                   ..                 ..
# 185    26.4                 19.2               25.0
# 184    26.4                 19.2               25.0
# 183    26.4                 19.2               25.0
# 182    23.5                 17.4               22.1
# 0      23.2                 18.3               22.0
#
#        Heating DB 99.6% - EPW  Heating DB 99% - EPW  Cooling DB 0.4% - EPW  \
# 26468 -6.6000                 -4.841                 35.1000
# 26419  10.2072                 11.000                19.9000
# 26430 -19.6964                -18.200                27.3000
# 26429 -12.1000                -10.700                26.7000
# 26428 -13.5000                -11.600                27.0000
# ...        ...                    ...                    ...
# 185   -5.9640                 -3.000                 30.0000
# 184   -5.0000                 -4.000                 30.0000
# 183   -6.0000                 -4.000                 29.8000
# 182   -7.5000                 -5.941                 25.4000
# 0     -8.1000                 -5.900                 30.1964
#
#        Cooling DB 1% - EPW  Region_number   Region
# 26468  33.900               99             Oceania
# 26419  18.600               99             Oceania
# 26430  25.341               99             Oceania
# 26429  25.841               99             Oceania
# 26428  26.000               99             Oceania
# ...       ...               ..                 ...
# 185    28.000               10             Europe
# 184    28.000               10             Europe
# 183    27.841               10             Europe
# 182    23.941               10             Europe
# 0      27.841               10             Europe
#
# [30463 rows x 27 columns]

# %%
df_results['delta - Heating DB 99.6%'] = df_results['Heating DB 99.6%'] - df_results['Heating DB 99.6% - EPW']
df_results['delta - Heating DB 99%'] = df_results['Heating DB 99%'] - df_results['Heating DB 99% - EPW']
df_results['delta - Cooling DB 0.4%'] = df_results['Cooling DB 0.4%'] - df_results['Cooling DB 0.4% - EPW']
df_results['delta - Cooling DB 1%'] = df_results['Cooling DB 1%'] - df_results['Cooling DB 1% - EPW']
df_results
# Out:
#                             Location Name                         Coordinates  \
# 26468  Philadelphia.Harbor PA USA          ['-75.14200', '39.93300', '20.0']
# 26419  Santa.Rosa.Island CA USA            ['-120.1030', '33.93890', '236.0']
# 26430  Marquette.Harbor.Lighthouse MI USA  ['-87.37625', '46.54660', '187.5']
# 26429  CGS.Ludington MI USA                ['-86.44100', '43.94700', '179.4']
# 26428  Ludington.Harbor MI USA             ['-86.44100', '43.94700', '179.4']
# ...                        ...                                            ...
# 185    Koln.Bonn.AP NW DEU                 ['7.15750', '50.86440', '99.5']
# 184    Koln.Bonn.AP NW DEU                 ['7.15750', '50.86440', '99.5']
# 183    Koln.Bonn.AP NW DEU                 ['7.15750', '50.86440', '99.5']
# 182    Nurburg.Barweiler RP DEU            ['6.86970', '50.36030', '488.2']
# 0      Bremerhaven HB DEU                  ['8.58300', '53.53300', '5.0']
#
#           WMO last_year  Country  Latitude Longitude  Heating DB 99.6%  \
# 26468  997286  2021      USA      39.9330N  75.1420W -9.4
# 26419  997199  2021      USA      33.677N   120.213W  9.9
# 26430  997262  2018      USA      46.546N   87.379W  -20.0
# 26429  997261  TMYx      USA      43.947N   86.441W  -15.3
# 26428  997261  2021      USA      43.947N   86.441W  -15.3
# ...       ...   ...      ...          ...       ...    ...
# 185    105130  2018      Germany  50.8644N  7.1575E  -8.0
# 184    105130  2021      Germany  50.8644N  7.1575E  -8.0
# 183    105130  TMYx      Germany  50.8644N  7.1575E  -8.0
# 182    105060  2018      Germany  50.3603N  6.8697E  -9.7
# 0      101290  BBSR      Germany  53.5333N  8.5761E  -9.4
#
#        Heating DB 99%  Cooling DB 0.4%  ...  Heating DB 99.6% - EPW  \
# 26468 -7.2             35.3             ... -6.6000
# 26419  10.3            20.5             ...  10.2072
# 26430 -17.9            27.5             ... -19.6964
# 26429 -13.2            27.0             ... -12.1000
# 26428 -13.2            27.0             ... -13.5000
# ...     ...             ...             ...      ...
# 185   -5.8             31.1             ... -5.9640
# 184   -5.8             31.1             ... -5.0000
# 183   -5.8             31.1             ... -6.0000
# 182   -7.7             27.6             ... -7.5000
# 0     -7.0             27.2             ... -8.1000
#
#        Heating DB 99% - EPW  Cooling DB 0.4% - EPW  Cooling DB 1% - EPW  \
# 26468 -4.841                 35.1000                33.900
# 26419  11.000                19.9000                18.600
# 26430 -18.200                27.3000                25.341
# 26429 -10.700                26.7000                25.841
# 26428 -11.600                27.0000                26.000
# ...       ...                    ...                   ...
# 185   -3.000                 30.0000                28.000
# 184   -4.000                 30.0000                28.000
# 183   -4.000                 29.8000                27.841
# 182   -5.941                 25.4000                23.941
# 0     -5.900                 30.1964                27.841
#
#        Region_number   Region  delta - Heating DB 99.6%  \
# 26468  99             Oceania -2.8000
# 26419  99             Oceania -0.3072
# 26430  99             Oceania -0.3036
# 26429  99             Oceania -3.2000
# 26428  99             Oceania -1.8000
# ...    ..                 ...     ...
# 185    10             Europe  -2.0360
# 184    10             Europe  -3.0000
# 183    10             Europe  -2.0000
# 182    10             Europe  -2.2000
# 0      10             Europe  -1.3000
#
#        delta - Heating DB 99%  delta - Cooling DB 0.4%  delta - Cooling DB 1%
# 26468 -2.359                   0.2000                   0.000
# 26419 -0.700                   0.6000                   1.300
# 26430  0.300                   0.2000                   0.359
# 26429 -2.500                   0.3000                   0.059
# 26428 -1.600                   0.0000                  -0.100
# ...      ...                      ...                     ...
# 185   -2.800                   1.1000                   0.900
# 184   -1.800                   1.1000                   0.900
# 183   -1.800                   1.3000                   1.059
# 182   -1.759                   2.2000                   1.559
# 0     -1.100                  -2.9964                  -2.741
#
# [30463 rows x 31 columns]

# %%
df_results['Country'].nunique()
# Out:
# 212

# %%
df_results['Region'].unique()
# Out:
# ['Oceania', 'South America', 'North America', 'special', 'Africa', 'Asia', 'Europe']
# Categories (8, object): ['Europe' < 'Asia' < 'Africa' < 'special' < 'North America' < 'South America' < 'Oceania' < 'other']

# %%
#For TMYx data only
df_TMY = df_results
df_TMY = df_TMY[df_TMY['last_year'].isin(['TMYx'])]
df_results = df_TMY
df_results
# Out:
#                              Location Name  \
# 26693  Interlaken.AP BE CHE
# 26696  St.Moritz-Samedam-Engadin.AP GR CHE
# 26697  St.Gallen SG CHE
# 26698  Bardufoss.AP TR NOR
# 26700  Hattula.Lepaa.AWS KH FIN
# ...                         ...
# 5161   Yerevan-Erebuni.AP ER ARM
# 5140   Amasia SH ARM
# 5141   Gyumri SH ARM
# 5145   Lake.Sevan GR ARM
# 5142   Sevan GR ARM
#
#                               Coordinates     WMO last_year      Country  \
# 26693  ['7.87030', '46.67220', '578.6']    67340   TMYx      Switzerland
# 26696  ['9.87890', '46.52640', '1709.2']   67920   TMYx      Switzerland
# 26697  ['9.39860', '47.42560', '777.8']    66810   TMYx      Switzerland
# 26698  ['18.54000', '69.05600', '76.8']    10230   TMYx      Norway
# 26700  ['24.32440', '61.11470', '87.0']    27040   TMYx      Finland
# ...                                 ...      ...    ...          ...
# 5161   ['44.53000', '40.21200', '901.0']   377890  TMYx      Armenia
# 5140   ['43.78300', '40.95000', '1866.0']  376820  TMYx      Armenia
# 5141   ['43.85600', '40.76300', '1512.0']  376860  TMYx      Armenia
# 5145   ['45.00830', '40.56580', '1917.0']  377170  TMYx      Armenia
# 5142   ['44.93300', '40.55000', '1937.0']  377090  TMYx      Armenia
#
#        Latitude Longitude  Heating DB 99.6%  Heating DB 99%  Cooling DB 0.4%  \
# 26693  46.6722N  7.8703E  -8.3              -6.6             29.3
# 26696  46.5261N  9.8794E  -22.7             -20.6            23.1
# 26697  47.4256N  9.3986E  -10.0             -8.1             27.1
# 26698  69.056N   18.540E  -26.2             -24.0            24.0
# 26700  61.115N   24.324E  -23.6             -20.0            27.7
# ...        ...       ...    ...               ...             ...
# 5161   40.212N   44.530E  -13.1             -10.7            36.1
# 5140   40.950N   43.784E  -19.0             -16.7            27.0
# 5141   40.763N   43.856E  -23.1             -20.9            31.9
# 5145   40.5653N  45.0083E -13.5             -11.7            25.0
# 5142   40.550N   44.933E  -17.9             -15.3            24.0
#
#        ...  Heating DB 99.6% - EPW  Heating DB 99% - EPW  \
# 26693  ... -23.8964                -22.000
# 26696  ... -21.1000                -20.041
# 26697  ... -16.5964                -15.400
# 26698  ... -15.9000                -15.200
# 26700  ... -23.9000                -18.682
# ...    ...      ...                    ...
# 5161   ... NaN                     NaN
# 5140   ... NaN                     NaN
# 5141   ... NaN                     NaN
# 5145   ... NaN                     NaN
# 5142   ... NaN                     NaN
#
#        Cooling DB 0.4% - EPW  Cooling DB 1% - EPW  Region_number  Region  \
# 26693  6.0000                 5.000                67             Africa
# 26696  9.6000                 8.200                67             Africa
# 26697  13.7964                12.300               66             Africa
# 26698  9.6000                 9.141                10             Europe
# 26700  15.6000                14.000               27             Europe
# ...        ...                   ...               ..                ...
# 5161  NaN                    NaN                   37             Asia
# 5140  NaN                    NaN                   37             Asia
# 5141  NaN                    NaN                   37             Asia
# 5145  NaN                    NaN                   37             Asia
# 5142  NaN                    NaN                   37             Asia
#
#        delta - Heating DB 99.6%  delta - Heating DB 99%  \
# 26693  15.5964                   15.400
# 26696 -1.6000                   -0.559
# 26697  6.5964                    7.300
# 26698 -10.3000                  -8.800
# 26700  0.3000                   -1.318
# ...       ...                      ...
# 5161  NaN                       NaN
# 5140  NaN                       NaN
# 5141  NaN                       NaN
# 5145  NaN                       NaN
# 5142  NaN                       NaN
#
#        delta - Cooling DB 0.4%  delta - Cooling DB 1%
# 26693  23.3000                  22.300
# 26696  13.5000                  13.400
# 26697  13.3036                  13.200
# 26698  14.4000                  12.759
# 26700  12.1000                  11.700
# ...        ...                     ...
# 5161  NaN                      NaN
# 5140  NaN                      NaN
# 5141  NaN                      NaN
# 5145  NaN                      NaN
# 5142  NaN                      NaN
#
# [8856 rows x 31 columns]

# %%
df_results.plot.scatter(x="Heating DB 99%", y="Heating DB 99% - EPW", s=5);

# %%
df_results.plot.scatter(x="Heating DB 99.6%", y="Heating DB 99.6% - EPW", s=5);

# %%
df_results.plot.scatter(x="Cooling DB 0.4%", y="Cooling DB 0.4% - EPW", s=5);

# %%
df_results.plot.scatter(x="Cooling DB 1%", y="Cooling DB 1% - EPW", s=5);

# %%
#sort by largest to smallest error and plot histogram
df_results= df_results.sort_values(by=['delta - Heating DB 99.6%'], ascending=False)
df_results.head()
# Out:
#                                                Location Name  \
# 14294  Capmon.CS-Saturna.Island BC CAN
# 11813  Brockville-Tackaberry.Thousand.Islands.Rgnl.AP ON CAN
# 14428  Cheticamp.CS NS CAN
# 26693  Interlaken.AP BE CHE
# 14313  Baccaro.Point NS CAN
#
#                               Coordinates     WMO last_year      Country  \
# 14294  ['-123.1281', '48.77530', '178.0']  719140  TMYx      Canada
# 11813  ['-75.75160', '44.63540', '121.4']  711610  TMYx      Canada
# 14428  ['-60.94722', '46.64500', '44.0']   719590  TMYx      Canada
# 26693  ['7.87030', '46.67220', '578.6']    67340   TMYx      Switzerland
# 14313  ['-65.47170', '43.45080', '5.7']    719200  TMYx      Canada
#
#        Latitude  Longitude  Heating DB 99.6%  Heating DB 99%  Cooling DB 0.4%  \
# 14294  48.7753N  123.1281W -4.6              -2.9             26.7
# 11813  44.6354N  75.7516W  -24.5             -21.1            29.7
# 14428  46.650N   60.950W   -16.0             -13.7            27.3
# 26693  46.6722N  7.8703E   -8.3              -6.6             29.3
# 14313  43.4508N  65.4717W  -12.4             -10.2            20.0
#
#        ...  Heating DB 99.6% - EPW  Heating DB 99% - EPW  \
# 14294  ... -30.9640                -23.300
# 11813  ... -44.4820                -37.123
# 14428  ... -32.2964                -30.800
# 26693  ... -23.8964                -22.000
# 14313  ... -27.5892                -21.000
#
#        Cooling DB 0.4% - EPW  Cooling DB 1% - EPW  Region_number  \
# 14294  22.0000                21.000               71
# 11813  28.3964                26.700               71
# 14428  23.5964                22.100               71
# 26693  6.0000                 5.000                67
# 14313  24.2000                22.341               71
#
#               Region  delta - Heating DB 99.6%  delta - Heating DB 99%  \
# 14294  North America  26.3640                   20.400
# 11813  North America  19.9820                   16.023
# 14428  North America  16.2964                   17.100
# 26693  Africa         15.5964                   15.400
# 14313  North America  15.1892                   10.800
#
#        delta - Cooling DB 0.4%  delta - Cooling DB 1%
# 14294  4.7000                   3.800
# 11813  1.3036                   1.500
# 14428  3.7036                   3.800
# 26693  23.3000                  22.300
# 14313 -4.2000                  -3.441
#
# [5 rows x 31 columns]

# %%
plt.xlabel('degrees C +/- from 2021 ASHRAE Design Day Heating DB 99.6%',fontsize=20)
n, bins, patches = plt.hist(x= df_results['delta - Heating DB 99.6%'], bins='auto')
plt.rcParams['figure.figsize'] = [20, 12]
#plt.xticks(bins)
plt.show()

# %%
dist = df_results.drop(df_results.columns[0:27],axis=1)
dist
# Out:
#        delta - Heating DB 99.6%  delta - Heating DB 99%  \
# 14294  26.3640                   20.400
# 11813  19.9820                   16.023
# 14428  16.2964                   17.100
# 26693  15.5964                   15.400
# 14313  15.1892                   10.800
# ...        ...                      ...
# 5161  NaN                       NaN
# 5140  NaN                       NaN
# 5141  NaN                       NaN
# 5145  NaN                       NaN
# 5142  NaN                       NaN
#
#        delta - Cooling DB 0.4%  delta - Cooling DB 1%
# 14294  4.7000                   3.800
# 11813  1.3036                   1.500
# 14428  3.7036                   3.800
# 26693  23.3000                  22.300
# 14313 -4.2000                  -3.441
# ...       ...                     ...
# 5161  NaN                      NaN
# 5140  NaN                      NaN
# 5141  NaN                      NaN
# 5145  NaN                      NaN
# 5142  NaN                      NaN
#
# [8856 rows x 4 columns]

# %%
fig, ax = plt.subplots()
#dist.plot.kde(ax=ax, legend=False, title='delta Heating/Cooling DD')
dist.plot.hist(density=True, ax=ax, bins=60, alpha=0.5)
ax.set_ylabel('Probability')
ax.grid(axis='y')
#ax.set_facecolor('#d8dcd6')

# %%
dist.describe()
# Out:
#        delta - Heating DB 99.6%  delta - Heating DB 99%  \
# count  8824.000000               8824.000000
# mean  -1.166944                 -0.873673
# std    2.267308                  1.901744
# min   -27.100000                -25.200000
# 25%   -2.200000                 -1.700000
# 50%   -0.900000                 -0.700000
# 75%    0.000000                  0.100000
# max    26.364000                 20.400000
#
#        delta - Cooling DB 0.4%  delta - Cooling DB 1%
# count  8824.000000              8824.000000
# mean   0.722831                 0.564515
# std    1.169399                 0.993751
# min   -13.700000               -13.041000
# 25%    0.100000                 0.100000
# 50%    0.700000                 0.500000
# 75%    1.300000                 1.000000
# max    23.300000                22.300000

# %%
df_results= df_results.sort_values(by=['delta - Heating DB 99%'], ascending=False)
plt.xlabel('degrees C +/- from 2021 ASHRAE Design Day Heating DB 99%',fontsize=20)
plt.hist(x= df_results['delta - Heating DB 99%'], bins='auto')
plt.rcParams['figure.figsize'] = [20, 5]
plt.show()

# %%
df_results= df_results.sort_values(by=['delta - Cooling DB 0.4%'], ascending=False)
plt.xlabel('degrees C +/- from 2021 ASHRAE Design Day Cooling DB 0.4%',fontsize=20)
plt.hist(x= df_results['delta - Cooling DB 0.4%'], bins='auto')
plt.rcParams['figure.figsize'] = [20, 5]
plt.show()

# %%
df_results= df_results.sort_values(by=['delta - Cooling DB 1%'], ascending=False)
plt.xlabel('degrees C +/- from 2021 ASHRAE Design Day Cooling DB 1%',fontsize=20)
plt.hist(x= df_results['delta - Cooling DB 1%'], bins='auto')
plt.rcParams['figure.figsize'] = [20, 5]
plt.show()

# %%
n_by_country = df_results.groupby("Country")["WMO"].count()
n_by_country
# Out:
# Country
# Afghanistan                   4
# Albania                       4
# Algeria                       43
# AmericanSamoa                 1
# Antarctica                    49
#                               ..
# WesternSahara                 1
# Yemen                         2
# Zambia                        1
# Zimbabwe                      2
# theDemocraticRepublicofthe    1
# Name: WMO, Length: 212, dtype: int64

# %%
n_by_region = df_results.groupby("Region")["WMO"].count()
n_by_region
# Out:
# Region
# Europe           1974
# Asia             2081
# Africa           572
# special          3
# North America    2963
# South America    321
# Oceania          942
# other            0
# Name: WMO, dtype: int64

# %%
df_results.columns
# Out:
# Index(['Location Name', 'Coordinates', 'WMO', 'last_year', 'Country',
#        'Latitude', 'Longitude', 'Heating DB 99.6%', 'Heating DB 99%',
#        'Cooling DB 0.4%', 'Cooling MCWB 0.4%', 'Cooling DB 1%',
#        'Cooling MCWB 1%', 'Cooling DB 2%', 'Cooling MCWB 2%',
#        'Evaporation WB 0.4%', 'Evaporation MCDB 0.4%', 'Evaporation WB 1%',
#        'Evaporation MCDB 1%', 'Evaporation WB 2%', 'Evaporation MCDB 2%',
#        'Heating DB 99.6% - EPW', 'Heating DB 99% - EPW',
#        'Cooling DB 0.4% - EPW', 'Cooling DB 1% - EPW', 'Region_number',
#        'Region', 'delta - Heating DB 99.6%', 'delta - Heating DB 99%',
#        'delta - Cooling DB 0.4%', 'delta - Cooling DB 1%'],
#       dtype='object')

# %%
df_results = df_results.reset_index()
df_results = df_results.drop(columns=['index'])
df_results.to_csv('All_Results_TMYx.csv')
df_results
# Out:
#       level_0                                          Location Name  \
# 0     0        Capmon.CS-Saturna.Island BC CAN
# 1     1        Brockville-Tackaberry.Thousand.Islands.Rgnl.AP ON CAN
# 2     2        Cheticamp.CS NS CAN
# 3     3        Interlaken.AP BE CHE
# 4     4        Baccaro.Point NS CAN
# ...  ..                         ...
# 8851  8851     Yerevan-Erebuni.AP ER ARM
# 8852  8852     Amasia SH ARM
# 8853  8853     Gyumri SH ARM
# 8854  8854     Lake.Sevan GR ARM
# 8855  8855     Sevan GR ARM
#
#                              Coordinates     WMO last_year      Country  \
# 0     ['-123.1281', '48.77530', '178.0']  719140  TMYx      Canada
# 1     ['-75.75160', '44.63540', '121.4']  711610  TMYx      Canada
# 2     ['-60.94722', '46.64500', '44.0']   719590  TMYx      Canada
# 3     ['7.87030', '46.67220', '578.6']    67340   TMYx      Switzerland
# 4     ['-65.47170', '43.45080', '5.7']    719200  TMYx      Canada
# ...                                ...       ...   ...         ...
# 8851  ['44.53000', '40.21200', '901.0']   377890  TMYx      Armenia
# 8852  ['43.78300', '40.95000', '1866.0']  376820  TMYx      Armenia
# 8853  ['43.85600', '40.76300', '1512.0']  376860  TMYx      Armenia
# 8854  ['45.00830', '40.56580', '1917.0']  377170  TMYx      Armenia
# 8855  ['44.93300', '40.55000', '1937.0']  377090  TMYx      Armenia
#
#       Latitude  Longitude  Heating DB 99.6%  Heating DB 99%  ...  \
# 0     48.7753N  123.1281W -4.6              -2.9             ...
# 1     44.6354N  75.7516W  -24.5             -21.1            ...
# 2     46.650N   60.950W   -16.0             -13.7            ...
# 3     46.6722N  7.8703E   -8.3              -6.6             ...
# 4     43.4508N  65.4717W  -12.4             -10.2            ...
# ...        ...       ...    ...               ...            ...
# 8851  40.212N   44.530E   -13.1             -10.7            ...
# 8852  40.950N   43.784E   -19.0             -16.7            ...
# 8853  40.763N   43.856E   -23.1             -20.9            ...
# 8854  40.5653N  45.0083E  -13.5             -11.7            ...
# 8855  40.550N   44.933E   -17.9             -15.3            ...
#
#       Heating DB 99.6% - EPW  Heating DB 99% - EPW  Cooling DB 0.4% - EPW  \
# 0    -30.9640                -23.300                22.0000
# 1    -44.4820                -37.123                28.3964
# 2    -32.2964                -30.800                23.5964
# 3    -23.8964                -22.000                6.0000
# 4    -27.5892                -21.000                24.2000
# ...       ...                    ...                    ...
# 8851 NaN                     NaN                   NaN
# 8852 NaN                     NaN                   NaN
# 8853 NaN                     NaN                   NaN
# 8854 NaN                     NaN                   NaN
# 8855 NaN                     NaN                   NaN
#
#       Cooling DB 1% - EPW  Region_number         Region  \
# 0     21.000               71             North America
# 1     26.700               71             North America
# 2     22.100               71             North America
# 3     5.000                67             Africa
# 4     22.341               71             North America
# ...      ...               ..                       ...
# 8851 NaN                   37             Asia
# 8852 NaN                   37             Asia
# 8853 NaN                   37             Asia
# 8854 NaN                   37             Asia
# 8855 NaN                   37             Asia
#
#       delta - Heating DB 99.6%  delta - Heating DB 99%  \
# 0     26.3640                   20.400
# 1     19.9820                   16.023
# 2     16.2964                   17.100
# 3     15.5964                   15.400
# 4     15.1892                   10.800
# ...       ...                      ...
# 8851 NaN                       NaN
# 8852 NaN                       NaN
# 8853 NaN                       NaN
# 8854 NaN                       NaN
# 8855 NaN                       NaN
#
#       delta - Cooling DB 0.4%  delta - Cooling DB 1%
# 0     4.7000                   3.800
# 1     1.3036                   1.500
# 2     3.7036                   3.800
# 3     23.3000                  22.300
# 4    -4.2000                  -3.441
# ...      ...                     ...
# 8851 NaN                      NaN
# 8852 NaN                      NaN
# 8853 NaN                      NaN
# 8854 NaN                      NaN
# 8855 NaN                      NaN
#
# [8856 rows x 32 columns]

# %%
df_summary = df_results.drop(columns=['Coordinates','Heating DB 99.6%','Heating DB 99%','Cooling DB 0.4%', 'Cooling MCWB 0.4%', 'Cooling DB 1%',
       'Cooling MCWB 1%', 'Cooling DB 2%', 'Cooling MCWB 2%',
       'Evaporation WB 0.4%', 'Evaporation MCDB 0.4%', 'Evaporation WB 1%',
       'Evaporation MCDB 1%', 'Evaporation WB 2%', 'Evaporation MCDB 2%',
       'Heating DB 99.6% - EPW', 'Heating DB 99% - EPW',
       'Cooling DB 0.4% - EPW', 'Cooling DB 1% - EPW', 'Region_number'])

# %%
cnt_min = df_summary.groupby(["Region"]).min()
cnt_min
# Out:
#                                  Location Name     WMO last_year  \
# Region
# Europe         Aachen NW DEU                    100001  TMYx
# Asia           Aasiaat-Egedesminde QA GRL       30010   TMYx
# Africa         Aadorf.Tanikon TG CHE            600200  TMYx
# special        Bagram.AP PAR AFG                690150  TMYx
# North America  Abbeville-Crusta.Meml.AP LA USA  700001  TMYx
# South America  A.Coruna GA ESP                  800010  TMYx
# Oceania        Adelaide-Kent.Town SA AUS        910660  TMYx
# other          NaN                              NaN     <NA>
#
#                          Country Latitude  Longitude  \
# Region
# Europe         Albania            34.590N  1.829E
# Asia           Afghanistan        0.6905S  0.055E
# Africa         Algeria            0.042N   0.033W
# special        Afghanistan        34.300N  116.167W
# North America  AntiguaandBarbuda  10.595N  0.0000E
# South America  Antarctica         0.0451S  0.475W
# Oceania        AmericanSamoa      0.0657N  100.2892E
# other          NaN                NaN      NaN
#
#                delta - Heating DB 99.6%  delta - Heating DB 99%  \
# Region
# Europe        -27.1000                  -25.2
# Asia          -12.8000                  -12.0
# Africa        -17.0036                  -15.9
# special       -3.9000                   -4.0
# North America -16.0000                  -14.8
# South America -11.7000                  -8.5
# Oceania       -5.5072                   -4.3
# other         NaN                       NaN
#
#                delta - Cooling DB 0.4%  delta - Cooling DB 1%
# Region
# Europe        -13.7                    -13.041
# Asia          -4.4                     -3.800
# Africa        -7.6                     -7.600
# special        0.7                      0.400
# North America -5.0                     -4.200
# South America -6.1                     -6.300
# Oceania       -3.0                     -2.400
# other         NaN                      NaN

# %%
cnt_region = df_summary.groupby(["Region"])
cnt_region.describe()
# Out:
#               delta - Heating DB 99.6%                                       \
#                                  count      mean       std      min     25%
# Region
# Europe         1974.0                  -2.231661  2.952980 -27.1000 -3.8786
# Asia           2059.0                  -0.811302  1.738783 -12.8000 -1.5036
# Africa         568.0                   -0.891031  2.125333 -17.0036 -2.0000
# special        3.0                     -0.766667  2.730079 -3.9000  -1.7000
# North America  2962.0                  -1.040116  2.202701 -16.0000 -2.2000
# South America  317.0                   -0.536998  1.680883 -11.7000 -1.2000
# Oceania        941.0                   -0.490847  1.004583 -5.5072  -0.8000
# other          0.0                     NaN       NaN       NaN      NaN
#
#                                        delta - Heating DB 99%            ...  \
#                   50%     75%      max                  count      mean  ...
# Region                                                                   ...
# Europe        -2.0000 -0.5000  9.7964   1974.0                -1.710231  ...
# Asia          -0.6000  0.1000  8.4964   2059.0                -0.551562  ...
# Africa        -0.6000  0.1196  15.5964  568.0                 -0.617104  ...
# special        0.5000  0.8000  1.1000   3.0                   -0.733333  ...
# North America -1.1000  0.0000  26.3640  2962.0                -0.790832  ...
# South America -0.4000  0.2000  5.4000   317.0                 -0.401284  ...
# Oceania       -0.3036  0.0000  3.4964   941.0                 -0.398794  ...
# other         NaN     NaN     NaN       0.0                   NaN        ...
#
#               delta - Cooling DB 0.4%          delta - Cooling DB 1%  \
#                                   75%      max                 count
# Region
# Europe         1.9000                  14.4000  1974.0
# Asia           1.2036                  7.2000   2059.0
# Africa         1.1090                  23.3000  568.0
# special        1.7018                  2.3000   3.0
# North America  1.1000                  9.7036   2962.0
# South America  1.0000                  7.3000   317.0
# Oceania        0.8000                  3.4000   941.0
# other         NaN                     NaN       0.0
#
#
#                    mean       std     min    25%    50%     75%     max
# Region
# Europe         0.863935  1.217494 -13.041  0.200  0.900  1.5000  12.759
# Asia           0.604324  0.825298 -3.800   0.100  0.559  1.0000  6.500
# Africa         0.650741  1.646884 -7.600   0.100  0.500  0.9590  22.300
# special        1.200000  1.058301  0.400   0.600  0.800  1.6000  2.400
# North America  0.407684  0.783880 -4.200  -0.041  0.400  0.8135  10.600
# South America  0.421852  1.090482 -6.300   0.000  0.300  0.9000  7.359
# Oceania        0.336934  0.599455 -2.400   0.000  0.300  0.6000  3.600
# other         NaN       NaN       NaN     NaN    NaN    NaN     NaN
#
# [8 rows x 32 columns]

# %%
cnt_region.describe().to_csv('All_Results_Stats.csv')

# %%
cnt_max = df_summary.groupby(["Region"]).max()
cnt_max
# Out:
#                            Location Name     WMO last_year  \
# Region
# Europe         Zyryanka SA RUS            299740  TMYx
# Asia           Zunyi-Huichuan GZ CHN      599850  TMYx
# Africa         Zuwara NQ LBY              689940  TMYx
# special        Vaduz VA LIE               69900   TMYx
# North America  Zapata.County.AP TX USA    789900  TMYx
# South America  Zaragoza.AP AR ESP         898790  TMYx
# Oceania        Zamboanga.Intl.AP ZAM PHL  998235  TMYx
# other          NaN                        NaN     <NA>
#
#                                   Country  Latitude Longitude  \
# Region
# Europe         Turkey                      80.626N   99.542E
# Asia           Yemen                       9.946N    99.9976E
# Africa         theDemocraticRepublicofthe  9.350N    9.9881E
# special        USA                         47.1275N  9.5175E
# North America  USA                         9.9892N   99.9686W
# South America  Venezuela                   9.869S    93.010E
# Oceania        WallisandFutuna             9.806S    98.889E
# other          NaN                         NaN       NaN
#
#                delta - Heating DB 99.6%  delta - Heating DB 99%  \
# Region
# Europe         9.7964                    9.541
# Asia           8.4964                    7.700
# Africa         15.5964                   15.400
# special        1.1000                    1.700
# North America  26.3640                   20.400
# South America  5.4000                    5.800
# Oceania        3.4964                    2.441
# other         NaN                       NaN
#
#                delta - Cooling DB 0.4%  delta - Cooling DB 1%
# Region
# Europe         14.4000                  12.759
# Asia           7.2000                   6.500
# Africa         23.3000                  22.300
# special        2.3000                   2.400
# North America  9.7036                   10.600
# South America  7.3000                   7.359
# Oceania        3.4000                   3.600
# other         NaN                      NaN

# %%
cnt_avg = df_summary.groupby(["Region"]).mean()
cnt_avg
# Out:
#                delta - Heating DB 99.6%  delta - Heating DB 99%  \
# Region
# Europe        -2.231661                 -1.710231
# Asia          -0.811302                 -0.551562
# Africa        -0.891031                 -0.617104
# special       -0.766667                 -0.733333
# North America -1.040116                 -0.790832
# South America -0.536998                 -0.401284
# Oceania       -0.490847                 -0.398794
# other         NaN                       NaN
#
#                delta - Cooling DB 0.4%  delta - Cooling DB 1%
# Region
# Europe         1.107662                 0.863935
# Asia           0.743973                 0.604324
# Africa         0.752915                 0.650741
# special        1.367867                 1.200000
# North America  0.560521                 0.407684
# South America  0.541762                 0.421852
# Oceania        0.420972                 0.336934
# other         NaN                      NaN

# %%
df_summary.groupby(["Region"]).boxplot()
# Out:
# Europe           AxesSubplot(0.1,0.679412;0.235294x0.220588)
# Asia             AxesSubplot(0.382353,0.679412;0.235294x0.220588)
# Africa           AxesSubplot(0.664706,0.679412;0.235294x0.220588)
# special          AxesSubplot(0.1,0.414706;0.235294x0.220588)
# North America    AxesSubplot(0.382353,0.414706;0.235294x0.220588)
# South America    AxesSubplot(0.664706,0.414706;0.235294x0.220588)
# Oceania          AxesSubplot(0.1,0.15;0.235294x0.220588)
# other            AxesSubplot(0.382353,0.15;0.235294x0.220588)
# dtype: object

# %%
plt.figure(figsize=(17,10))
ax = sns.boxplot(x="Region",y='delta - Heating DB 99.6%', data=df_summary)
ax.set( yticks=np.arange(-30,32,2))
plt.title('delta - Heating DB 99.6%')

plt.show()

# %%
plt.figure(figsize=(17,10))
ax = sns.boxenplot(x="Region",y='delta - Heating DB 99.6%', data=df_summary)
ax.set( yticks=np.arange(-30,32,2))
plt.title('delta - Heating DB 99.6%')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
plt.suptitle('')
df_summary.boxplot(column=['delta - Heating DB 99.6%'], by='Region', ax=ax)
# Out:
# <AxesSubplot:title={'center':'delta - Heating DB 99.6%'}, xlabel='Region'>

# %%
df_results= df_results.sort_values(by=['delta - Heating DB 99.6%'], ascending=False)
df_results
# Out:
#                                                Location Name  \
# 14294  Capmon.CS-Saturna.Island BC CAN
# 11813  Brockville-Tackaberry.Thousand.Islands.Rgnl.AP ON CAN
# 14428  Cheticamp.CS NS CAN
# 26693  Interlaken.AP BE CHE
# 14313  Baccaro.Point NS CAN
# ...                     ...
# 5161   Yerevan-Erebuni.AP ER ARM
# 5140   Amasia SH ARM
# 5141   Gyumri SH ARM
# 5145   Lake.Sevan GR ARM
# 5142   Sevan GR ARM
#
#                               Coordinates     WMO last_year      Country  \
# 14294  ['-123.1281', '48.77530', '178.0']  719140  TMYx      Canada
# 11813  ['-75.75160', '44.63540', '121.4']  711610  TMYx      Canada
# 14428  ['-60.94722', '46.64500', '44.0']   719590  TMYx      Canada
# 26693  ['7.87030', '46.67220', '578.6']    67340   TMYx      Switzerland
# 14313  ['-65.47170', '43.45080', '5.7']    719200  TMYx      Canada
# ...                                 ...       ...   ...         ...
# 5161   ['44.53000', '40.21200', '901.0']   377890  TMYx      Armenia
# 5140   ['43.78300', '40.95000', '1866.0']  376820  TMYx      Armenia
# 5141   ['43.85600', '40.76300', '1512.0']  376860  TMYx      Armenia
# 5145   ['45.00830', '40.56580', '1917.0']  377170  TMYx      Armenia
# 5142   ['44.93300', '40.55000', '1937.0']  377090  TMYx      Armenia
#
#        Latitude  Longitude  Heating DB 99.6%  Heating DB 99%  Cooling DB 0.4%  \
# 14294  48.7753N  123.1281W -4.6              -2.9             26.7
# 11813  44.6354N  75.7516W  -24.5             -21.1            29.7
# 14428  46.650N   60.950W   -16.0             -13.7            27.3
# 26693  46.6722N  7.8703E   -8.3              -6.6             29.3
# 14313  43.4508N  65.4717W  -12.4             -10.2            20.0
# ...         ...       ...    ...               ...             ...
# 5161   40.212N   44.530E   -13.1             -10.7            36.1
# 5140   40.950N   43.784E   -19.0             -16.7            27.0
# 5141   40.763N   43.856E   -23.1             -20.9            31.9
# 5145   40.5653N  45.0083E  -13.5             -11.7            25.0
# 5142   40.550N   44.933E   -17.9             -15.3            24.0
#
#        ...  Heating DB 99.6% - EPW  Heating DB 99% - EPW  \
# 14294  ... -30.9640                -23.300
# 11813  ... -44.4820                -37.123
# 14428  ... -32.2964                -30.800
# 26693  ... -23.8964                -22.000
# 14313  ... -27.5892                -21.000
# ...    ...      ...                    ...
# 5161   ... NaN                     NaN
# 5140   ... NaN                     NaN
# 5141   ... NaN                     NaN
# 5145   ... NaN                     NaN
# 5142   ... NaN                     NaN
#
#        Cooling DB 0.4% - EPW  Cooling DB 1% - EPW  Region_number  \
# 14294  22.0000                21.000               71
# 11813  28.3964                26.700               71
# 14428  23.5964                22.100               71
# 26693  6.0000                 5.000                67
# 14313  24.2000                22.341               71
# ...        ...                   ...               ..
# 5161  NaN                    NaN                   37
# 5140  NaN                    NaN                   37
# 5141  NaN                    NaN                   37
# 5145  NaN                    NaN                   37
# 5142  NaN                    NaN                   37
#
#               Region  delta - Heating DB 99.6%  delta - Heating DB 99%  \
# 14294  North America  26.3640                   20.400
# 11813  North America  19.9820                   16.023
# 14428  North America  16.2964                   17.100
# 26693  Africa         15.5964                   15.400
# 14313  North America  15.1892                   10.800
# ...              ...      ...                      ...
# 5161   Asia          NaN                       NaN
# 5140   Asia          NaN                       NaN
# 5141   Asia          NaN                       NaN
# 5145   Asia          NaN                       NaN
# 5142   Asia          NaN                       NaN
#
#        delta - Cooling DB 0.4%  delta - Cooling DB 1%
# 14294  4.7000                   3.800
# 11813  1.3036                   1.500
# 14428  3.7036                   3.800
# 26693  23.3000                  22.300
# 14313 -4.2000                  -3.441
# ...       ...                     ...
# 5161  NaN                      NaN
# 5140  NaN                      NaN
# 5141  NaN                      NaN
# 5145  NaN                      NaN
# 5142  NaN                      NaN
#
# [8856 rows x 31 columns]
